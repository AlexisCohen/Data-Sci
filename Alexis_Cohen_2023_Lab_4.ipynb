# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexisCohen/Data-Sci/blob/main/Alexis_Cohen_2023_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([12, 17, 18, 23, 56, 37, 48])
#This creates an array(list) of numbers

# %%
# population

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

#This gives back the mean of the list

# %%
def var(x):
    return mean((x - mean(x))**2)

  #This takes the mean and puts it in a formula where it is subtracted from the variable and put to the power of two

# %%
def std(x):
    return np.sqrt(var(x))

    #This square roots the variable x

# %%
mean(x)
#This is the result of the first formula
# Out:
# -4.999999999999982

# %%
var(x)
#This is the result of the second formula
# Out:
# 6616.749999999965

# %%
std(x)
#This is the result of the third formula
# Out:
# 81.34340784599551

# %% [markdown]
# ### Random Number Generator

# %%
m = 75                 # multiplier
b = 74                 # increment
n = 65537              # modulus

# %%
x = 123456      # seed value

# %%
X = np.zeros(50000,)
#This gives the variable X the array filled with zeros after the 50000

# %%
x = (m * x + b) % n
#This gives a new value to the variable x

# %%
for i in range(X.shape[0]):

    x = (m * x + b) % n
    
    X[i] = x

X /= np.max(X)

#This is a for loop that creates a range for the

# %%
plt.plot(X[:100],'.')
#This plots the X variable on a graph with a range of 100

# %%
plt.hist(X);
#this is a histogram of the variable X

# %%
plt.hist(X,100);
#This plots the variable X, and 100 on a histogram

# %%
X
#these are the variable in the X array
# Out:
# array([0.82162203, 0.62092012, 0.56873426, ..., 0.07512016, 0.63498894,
#        0.62386511])

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,)
#this now applies a list of random numbers to the X variable

# %%
plt.hist(X,100);
#This plots the variable X, and 100 on a histogram

# %%
np.random.random()
#this generates a random number
# Out:
# 0.3412927002110704

# %%
r = np.random.random()
#the variable r is assigned a randomly generated number

# %%
r
#this prints r's value
# Out:
# 0.7636333855896099

# %%
r = np.random.randint(1,10)
#this generates a random number from a range of 1 to 10

# %%
r
#this prints r
# Out:
# 9

# %%
r = np.random.randint(1,10,size=(10,2))
#this generates a random number from a range of 1 to 10
#and in a list of 10 pairs

# %%
r
#this prints r
# Out:
# array([[9, 2],
#        [9, 4],
#        [3, 1],
#        [4, 8],
#        [6, 8],
#        [1, 6],
#        [2, 1],
#        [3, 4],
#        [2, 3],
#        [3, 6]])

# %%
np.random.seed(12345)
data = np.random.randn(2, 100)

fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].hist(data[0])
axs[1, 0].scatter(data[0], data[1])
axs[0, 1].plot(data[0], data[1])
axs[1, 1].hist2d(data[0], data[1])

plt.show()

#This produces 4 seperate types of plots that have the random generated numbers plotted

# %% [markdown]
# Normal Dist Data

# %%
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# %%
n,bins,patches = plt.hist(x)

# %%
bins
# Out:
# array([ 47.67401067,  58.75290006,  69.83178945,  80.91067884,
#         91.98956823, 103.06845762, 114.14734702, 125.22623641,
#        136.3051258 , 147.38401519, 158.46290458])

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y)
#this plots y on a line graph

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)
#This plots the variables y and bins on both a histograph and a line graph

# %%
def mean(x):
    return np.sum(x)/x.shape[0]
  #this takes the mean of x by dividing it by x.shape

# %%
def var(x):
    return mean((x - mean(x))**2)

#this puts the mean through a formula to get var of X

# %%
def std(x):
    return np.sqrt(var(x))
#this square roots var(x)

# %%
mean(x)
#this prints mean(x)
# Out:
# 99.78475345251351

# %%
std(x)
#this prints the results of std(x)
# Out:
# 14.967403929980673

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
def normal_pdf(x,mu,sigma):
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2))
#this puts the variables x, mu, and sigma through the function normal_pdf

# %%
x = np.linspace(-6,6,1000)
#this creates steps 1000 steps from -6 to 6

# %%
mu = 0

# %%
sigma = 1

# %%
pdf = normal_pdf(x,mu,sigma) #Use Normal for demo, replace with custom function pdf

# %%
plt.plot(x,pdf,'.')

# %%
def partial_sums(x):

  y = np.zeros(x.shape)
  
  for n in range(x.shape[0]):
    
    y[n] = np.sum(x[0:n])
    
  y = y / np.max(y)
    
  return y

# %%
cdf = partial_sums(pdf)

# %%
plt.plot(x,cdf,'.');

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
plt.plot(cdf,x,'.');

# %%
def find_nearest(array, value):

  idx = np.argmin(np.abs(array - value))
  
  return idx

# %%
find_nearest(cdf, 0.1)
# Out:
# 393

# %%
x[393]
# Out:
# -1.2792792792792795

# %%
xr = np.random.random((10000,))

# %%
w = np.zeros(xr.shape[0])

for i in range(xr.shape[0]):
  
  w[i] = x[find_nearest(cdf, xr[i])]

# %%
w.shape
# Out:
# (10000,)

# %%
plt.hist(w,50);

# %%
num_bins = 50
n,bins,patches = plt.hist(w, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %% [markdown]
# # Random Color

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.random.randint(0,255,size=(10,10,3))
#generates an array of random numbers on a grid of 10 by 10

# %%
plt.imshow(z)
#this prints z and its random generated number as colors on a 10 by 10 grid

# %%
z = np.zeros((10,10,3))

# %%
plt.imshow(z)

# %%
z = 0*np.ones((10,10,3))

# %%
plt.imshow(z)
#this is all black because all of z values are 0

# %%
z = 255*np.ones((10,10,3))
#this makes all of the values as 255 which translates to white as a hexcode

# %%
plt.imshow(z)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3))

z[:,:,0] = 1
z[:,:,1] = 0
z[:,:,2] = 0

plt.imshow(z)
#hexcode for red

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z)
#hexcode for green

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 0
z[:,:,2] = 1

plt.imshow(z)
#hexcode for blue

# %%
z = np.ones((10,10,3))

r = np.random.rand()
g = np.random.rand()
b = np.random.rand()

print(r,g,b)

z[:,:,0] = r
z[:,:,1] = g
z[:,:,2] = b

plt.imshow(z);
#hexcode for brown
# Out:
# 0.6304571722364933 0.5470745554516485 0.3596978915396898

# %%
for i in range(10):

    z = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
    plt.show()
  #this code generates random hexcodes and then prints them on grids
# Out:
# 0.9805990578626729 0.806453747795892 0.19858446776138894
# 0.3155261477862573 0.8179793469028809 0.45662212504124045
# 0.8833119996314853 0.5030818466666976 0.2239938555281069
# 0.9569321909252053 0.9663753123151557 0.8957587908297052
# 0.3613121519949358 0.46860895269068703 0.5097844733262711
# 0.7497751997073729 0.49433815149867744 0.3203394646697221
# 0.982784089961498 0.1588338035501844 0.9625450982940932
# 0.7261830591768084 0.5631850105867038 0.451172353168386
# 0.8331726256911821 0.15668152829311444 0.7646749954109479
# 0.082809853243338 0.7236324117284484 0.659459813962211

# %%
z1 = np.ones((10,10,3))
z1[:,:,0] = np.random.rand()
z1[:,:,1] = np.random.rand()
z1[:,:,2] = np.random.rand()

z2 = np.ones((10,10,3))
z2[:,:,0] = np.random.rand()
z2[:,:,1] = np.random.rand()
z2[:,:,2] = np.random.rand()

z3 = np.hstack((z1,z2))

plt.imshow(z3);
plt.show()
#this code generates two hexcodes and prints them on two conjoined grids

# %%
for i in range(10):
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()
    #this code generates two hexcodes and prints them on two conjoined grids
    #it does this ten times

# %%
for i in range(10):
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()
  
  #this code generates two hexcodes and prints them on two conjoined grids
  #it does this ten times due to the for loop

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib
import imageio
from PIL import Image

def get_colors_lospec(url):
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %%
url = 'https://lospec.com/palette-list/agb-32x.png'

# %%
url = 'https://lospec.com/palette-list/agb-1x.png'

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png'

# %%
im = imageio.imread(url)

# %%
plt.imshow(im);

# %%
z = np.random.randint(0,255,size=(10,10))

# %%
plt.imshow(z, cmap=get_colors_lospec(url))
plt.colorbar();

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sqrt(x**2 + y**2)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)*np.sin(3*x)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
