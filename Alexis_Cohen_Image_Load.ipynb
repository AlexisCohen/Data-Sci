# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexisCohen/Data-Sci/blob/main/Alexis_Cohen_Image_Load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from skimage.io import imread

# %%
url = 'https://raw.githubusercontent.com/AlexisCohen/Data-Sci/main/Data%20Set/train/no%20spots/n1.jpg'

# %%
im = imread(url)

# %%
plt.figure(figsize=(10,10))
plt.imshow(im);
plt.axis('off');
